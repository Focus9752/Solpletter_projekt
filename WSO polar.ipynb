# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

#Importer Data fil
data = np.genfromtxt('WSO_polar2.csv', skip_header = 0, skip_footer = 0) 

#Lav arrays med 'sorteret' data, ud fra data filen
tid = data[:, 0]
N = data[:, 1]  #Nord
S = data[:, 2]  #Syd
Avg = data[:, 3] #Gennemsnitlig
Avg_abs = np.abs(Avg)

X = np.linspace(1976, 2024, len(data))

Avgf = data[:, 8]
Avgf_abs = np.abs(Avgf)

# %%
plt.plot(X, Avg_abs)

# %%
data2 = np.genfromtxt('Sunspot.csv', delimiter = ';', skip_header = 0, skip_footer = 0) 
dag = data2[:, 2]
dag_erstat = np.linspace(1749, 2024, len(data2))
solplet = data2[:, 3]

plt.plot(dag_erstat, solplet)
# Out:
# 3301
# 3301
# [nan nan nan ... nan nan nan]

# %%
plt.plot(dag_erstat, solplet)
plt.plot(X+6, Avg_abs)
plt.axis([1970, 2030, 0 , 400])
# Out:
# (1970.0, 2030.0, 0.0, 400.0)

# %% [markdown]
# Se på SOHO satelitten. ift. hvordan det blev taget senere.
# Vær opmærksom på dags tid.
# Hysterese - at det tager lidt tid om at det vender. Er der en systematik i forsinkelen. Fx forsinkelse fra magnetfelt til solplet antal.
# Hvad vil vi helst; flere data eller mere præcis data?
# Evt. lav en estimering for både det gamle og det præcise
# Wolf-cyklus og andre cykler. Se om der er andre større cykler.
#
# Forstå hvordan magnetfeltet laves. og hvor det er. Hvad påvirker hvad.
# Rotation.
#
# teskten skal handle om data
# Introduktionen skal være den som introducere andre førsteårsstuderende til emnet så de forstår. Resten skal være om data.
