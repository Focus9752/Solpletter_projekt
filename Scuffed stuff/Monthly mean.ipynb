# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt("Monthly mean.csv", delimiter=';')

år = data[:,0]
måned = data[:,1]
dato_fraction = data[:,2]
SSN = data[:,3]
std = data[:,4]
N = data[:,5]
definite = data[:,6]

# %%
plt.figure(figsize=[15,8])
plt.plot(dato_fraction, SSN, '.')
plt.title("Månedligt gennemsnit af Sunspot number", size=15)
plt.ylabel("Sunspot number")
plt.xlabel("Tid [år]");

# %% [markdown]
# ## **Der hvor data er lig en værdi**

# %%
def dato_lig(data, lig):
    indeks = []
    for i in range(len(data)):
        if data[i]==lig:
            indeks.append(i)
    count = 0
    print(f'Dataet={lig} {len(indeks)} gange, og sker ved måned(erne):')
    for i in range(len(indeks)):
        print(f'{måned[indeks[count]]} / {år[indeks[count]]}')
        count +=1

dato_lig(N, 0)
# Out:
# Dataet=0 1 gange, og sker ved måned(erne):
# 2.0 / 1824.0
