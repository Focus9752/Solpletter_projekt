# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
north = np.genfromtxt('sunspot_area_north.txt', skip_header=1)
north_år = north[:,0]
north_måned = north[:,1]
north_area = north[:,2]
plt.plot(north_år, north_area, '.')
